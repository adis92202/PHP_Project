# %% [markdown]
# # PHP 2022

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/9.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](../../edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](../../edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
#
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](../../edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comments/show.blade.php](../../edit/09_laravel_tdd/project/resources/views/comments/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 89644ce16d10edee4e8785bbec03398481c9dbf235c6c1865c23de06f5279116

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Edit the code:

# %%
! phpstorm project
# Out:
# CompileCommand: exclude com/intellij/openapi/vfs/impl/FilePartNodeRoot.trieDescend bool exclude = true
# 2023-01-13 11:52:29,897 [   1155]   WARN - #c.i.u.s.SvgCacheManager - Icon cache will be recreated or previous version of data reused, (db=/home/student/.cache/JetBrains/PhpStorm2022.2/icons-v6.db)
# 2023-01-13 11:52:30,212 [   1470] SEVERE - #c.i.d.LoadingState - Should be called at least in the state COMPONENTS_LOADED, the current state is: CONFIGURATION_STORE_INITIALIZED
# Current violators count: 1
#
#
# java.lang.Throwable
# 	at com.intellij.diagnostic.LoadingState.logStateError(LoadingState.java:52)
# 	at com.intellij.diagnostic.LoadingState.checkOccurred(LoadingState.java:48)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.<init>(ActionManagerImpl.java:133)
# 	at com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager.<init>(BackendActionManager.kt:17)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:480)
# 	at com.intellij.serviceContainer.ConstructorInjectionKt.instantiateUsingPicoContainer(constructorInjection.kt:47)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClassWithConstructorInjection(ComponentManagerImpl.kt:890)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.createAndInitialize(ServiceComponentAdapter.kt:51)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.doCreateInstance(ServiceComponentAdapter.kt:41)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstanceUncached(BaseComponentAdapter.kt:119)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance(BaseComponentAdapter.kt:73)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance$default(BaseComponentAdapter.kt:66)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.doGetService(ComponentManagerImpl.kt:609)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.getService(ComponentManagerImpl.kt:583)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getFromSelfOrCurrentSession(ClientAwareComponentManager.kt:37)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getService(ClientAwareComponentManager.kt:22)
# 	at com.intellij.openapi.actionSystem.ActionManager.getInstance(ActionManager.java:29)
# 	at com.intellij.help.impl.KeymapGenerator.<clinit>(KeymapGenerator.java:33)
# 	at java.base/jdk.internal.misc.Unsafe.allocateInstance(Native Method)
# 	at java.base/java.lang.invoke.DirectMethodHandle.allocateInstance(DirectMethodHandle.java:520)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClass(ComponentManagerImpl.kt:844)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.instantiateClass(XmlExtensionAdapter.kt:79)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter$SimpleConstructorInjectionAdapter.instantiateClass(XmlExtensionAdapter.kt:90)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.doCreateInstance(XmlExtensionAdapter.kt:50)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.createInstance(XmlExtensionAdapter.kt:31)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.processAdapter(ExtensionPointImpl.java:447)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.access$200(ExtensionPointImpl.java:33)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl$1.next(ExtensionPointImpl.java:355)
# 	at com.intellij.idea.ApplicationLoader.findAppStarter(ApplicationLoader.kt:595)
# 	at com.intellij.idea.ApplicationLoader.access$findAppStarter(ApplicationLoader.kt:1)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt:170)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1150)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$2.execute(ApplicationLoader.kt:142)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompletion.claim(CompletableFuture.java:572)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1147)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.exec(CompletableFuture.java:483)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool.externalHelpQuiescePool(ForkJoinPool.java:2104)
# 	at java.base/java.util.concurrent.ForkJoinPool.awaitQuiescence(ForkJoinPool.java:3321)
# 	at com.intellij.idea.StartupUtil.start(StartupUtil.java:272)
# 	at com.intellij.idea.Main.bootstrap(Main.java:119)
# 	at com.intellij.idea.Main.main(Main.java:81)
# 2023-01-13 11:52:30,243 [   1501] SEVERE - #c.i.d.LoadingState - PhpStorm 2022.2.3  Build #PS-222.4345.15
# 2023-01-13 11:52:30,245 [   1503] SEVERE - #c.i.d.LoadingState - JDK: 17.0.4.1; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2023-01-13 11:52:30,246 [   1504] SEVERE - #c.i.d.LoadingState - OS: Linux
# 2023-01-13 11:52:31,060 [   2318] SEVERE - #c.i.d.LoadingState - Should be called at least in the state COMPONENTS_LOADED, the current state is: CONFIGURATION_STORE_INITIALIZED
# Current violators count: 2
#
#
# java.lang.Throwable
# 	at com.intellij.diagnostic.LoadingState.logStateError(LoadingState.java:52)
# 	at com.intellij.diagnostic.LoadingState.checkOccurred(LoadingState.java:48)
# 	at com.intellij.openapi.util.registry.Registry.getInstance(Registry.java:176)
# 	at com.intellij.openapi.util.registry.Registry.get(Registry.java:50)
# 	at com.intellij.openapi.util.registry.Registry.is(Registry.java:63)
# 	at com.intellij.execution.ExecutorRegistryImpl.isExecutorInMainGroup(ExecutorRegistryImpl.java:195)
# 	at com.intellij.execution.ExecutorRegistryImpl.initExecutorActions(ExecutorRegistryImpl.java:127)
# 	at com.intellij.execution.ExecutorRegistryImpl.init(ExecutorRegistryImpl.java:278)
# 	at com.intellij.execution.ExecutorRegistryImpl$ExecutorRegistryActionConfigurationTuner.customize(ExecutorRegistryImpl.java:92)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.lambda$new$0(ActionManagerImpl.java:141)
# 	at com.intellij.openapi.extensions.impl.ExtensionProcessingHelper.forEachExtensionSafe(ExtensionProcessingHelper.java:34)
# 	at com.intellij.openapi.extensions.ExtensionPointName.forEachExtensionSafe(ExtensionPointName.java:46)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.<init>(ActionManagerImpl.java:141)
# 	at com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager.<init>(BackendActionManager.kt:17)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:480)
# 	at com.intellij.serviceContainer.ConstructorInjectionKt.instantiateUsingPicoContainer(constructorInjection.kt:47)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClassWithConstructorInjection(ComponentManagerImpl.kt:890)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.createAndInitialize(ServiceComponentAdapter.kt:51)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.doCreateInstance(ServiceComponentAdapter.kt:41)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstanceUncached(BaseComponentAdapter.kt:119)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance(BaseComponentAdapter.kt:73)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance$default(BaseComponentAdapter.kt:66)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.doGetService(ComponentManagerImpl.kt:609)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.getService(ComponentManagerImpl.kt:583)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getFromSelfOrCurrentSession(ClientAwareComponentManager.kt:37)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getService(ClientAwareComponentManager.kt:22)
# 	at com.intellij.openapi.actionSystem.ActionManager.getInstance(ActionManager.java:29)
# 	at com.intellij.help.impl.KeymapGenerator.<clinit>(KeymapGenerator.java:33)
# 	at java.base/jdk.internal.misc.Unsafe.allocateInstance(Native Method)
# 	at java.base/java.lang.invoke.DirectMethodHandle.allocateInstance(DirectMethodHandle.java:520)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClass(ComponentManagerImpl.kt:844)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.instantiateClass(XmlExtensionAdapter.kt:79)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter$SimpleConstructorInjectionAdapter.instantiateClass(XmlExtensionAdapter.kt:90)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.doCreateInstance(XmlExtensionAdapter.kt:50)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.createInstance(XmlExtensionAdapter.kt:31)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.processAdapter(ExtensionPointImpl.java:447)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.access$200(ExtensionPointImpl.java:33)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl$1.next(ExtensionPointImpl.java:355)
# 	at com.intellij.idea.ApplicationLoader.findAppStarter(ApplicationLoader.kt:595)
# 	at com.intellij.idea.ApplicationLoader.access$findAppStarter(ApplicationLoader.kt:1)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt:170)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1150)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$2.execute(ApplicationLoader.kt:142)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompletion.claim(CompletableFuture.java:572)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1147)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.exec(CompletableFuture.java:483)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool.externalHelpQuiescePool(ForkJoinPool.java:2104)
# 	at java.base/java.util.concurrent.ForkJoinPool.awaitQuiescence(ForkJoinPool.java:3321)
# 	at com.intellij.idea.StartupUtil.start(StartupUtil.java:272)
# 	at com.intellij.idea.Main.bootstrap(Main.java:119)
# 	at com.intellij.idea.Main.main(Main.java:81)
# 2023-01-13 11:52:31,068 [   2326] SEVERE - #c.i.d.LoadingState - PhpStorm 2022.2.3  Build #PS-222.4345.15
# 2023-01-13 11:52:31,069 [   2327] SEVERE - #c.i.d.LoadingState - JDK: 17.0.4.1; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2023-01-13 11:52:31,070 [   2328] SEVERE - #c.i.d.LoadingState - OS: Linux
# 2023-01-13 11:52:31,120 [   2378] SEVERE - #c.i.d.LoadingState - Should be called at least in the state COMPONENTS_LOADED, the current state is: CONFIGURATION_STORE_INITIALIZED
# Current violators count: 3
#
#
# java.lang.Throwable
# 	at com.intellij.diagnostic.LoadingState.logStateError(LoadingState.java:52)
# 	at com.intellij.diagnostic.LoadingState.checkOccurred(LoadingState.java:48)
# 	at com.intellij.openapi.util.registry.Registry.getInstance(Registry.java:176)
# 	at com.intellij.openapi.util.registry.Registry.get(Registry.java:50)
# 	at com.intellij.openapi.util.registry.Registry.is(Registry.java:63)
# 	at com.intellij.openapi.wm.impl.GlobalMenuLinux._loadLibrary(GlobalMenuLinux.java:797)
# 	at com.intellij.openapi.wm.impl.GlobalMenuLinux.<clinit>(GlobalMenuLinux.java:164)
# 	at com.intellij.openapi.wm.impl.GlobalMenuLinux$MyActionTuner.customize(GlobalMenuLinux.java:230)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.lambda$new$0(ActionManagerImpl.java:141)
# 	at com.intellij.openapi.extensions.impl.ExtensionProcessingHelper.forEachExtensionSafe(ExtensionProcessingHelper.java:34)
# 	at com.intellij.openapi.extensions.ExtensionPointName.forEachExtensionSafe(ExtensionPointName.java:46)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.<init>(ActionManagerImpl.java:141)
# 	at com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager.<init>(BackendActionManager.kt:17)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:480)
# 	at com.intellij.serviceContainer.ConstructorInjectionKt.instantiateUsingPicoContainer(constructorInjection.kt:47)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClassWithConstructorInjection(ComponentManagerImpl.kt:890)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.createAndInitialize(ServiceComponentAdapter.kt:51)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.doCreateInstance(ServiceComponentAdapter.kt:41)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstanceUncached(BaseComponentAdapter.kt:119)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance(BaseComponentAdapter.kt:73)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance$default(BaseComponentAdapter.kt:66)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.doGetService(ComponentManagerImpl.kt:609)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.getService(ComponentManagerImpl.kt:583)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getFromSelfOrCurrentSession(ClientAwareComponentManager.kt:37)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getService(ClientAwareComponentManager.kt:22)
# 	at com.intellij.openapi.actionSystem.ActionManager.getInstance(ActionManager.java:29)
# 	at com.intellij.help.impl.KeymapGenerator.<clinit>(KeymapGenerator.java:33)
# 	at java.base/jdk.internal.misc.Unsafe.allocateInstance(Native Method)
# 	at java.base/java.lang.invoke.DirectMethodHandle.allocateInstance(DirectMethodHandle.java:520)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClass(ComponentManagerImpl.kt:844)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.instantiateClass(XmlExtensionAdapter.kt:79)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter$SimpleConstructorInjectionAdapter.instantiateClass(XmlExtensionAdapter.kt:90)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.doCreateInstance(XmlExtensionAdapter.kt:50)
# 	at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.createInstance(XmlExtensionAdapter.kt:31)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.processAdapter(ExtensionPointImpl.java:447)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl.access$200(ExtensionPointImpl.java:33)
# 	at com.intellij.openapi.extensions.impl.ExtensionPointImpl$1.next(ExtensionPointImpl.java:355)
# 	at com.intellij.idea.ApplicationLoader.findAppStarter(ApplicationLoader.kt:595)
# 	at com.intellij.idea.ApplicationLoader.access$findAppStarter(ApplicationLoader.kt:1)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt:170)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$3.apply(ApplicationLoader.kt)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1150)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482)
# 	at com.intellij.idea.ApplicationLoader$initApplication$block$2.execute(ApplicationLoader.kt:142)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompletion.claim(CompletableFuture.java:572)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1147)
# 	at java.base/java.util.concurrent.CompletableFuture.postComplete(CompletableFuture.java:510)
# 	at java.base/java.util.concurrent.CompletableFuture.postFire(CompletableFuture.java:614)
# 	at java.base/java.util.concurrent.CompletableFuture$UniCompose.tryFire(CompletableFuture.java:1163)
# 	at java.base/java.util.concurrent.CompletableFuture$Completion.exec(CompletableFuture.java:483)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool.externalHelpQuiescePool(ForkJoinPool.java:2104)
# 	at java.base/java.util.concurrent.ForkJoinPool.awaitQuiescence(ForkJoinPool.java:3321)
# 	at com.intellij.idea.StartupUtil.start(StartupUtil.java:272)
# 	at com.intellij.idea.Main.bootstrap(Main.java:119)
# 	at com.intellij.idea.Main.main(Main.java:81)
# 2023-01-13 11:52:31,128 [   2386] SEVERE - #c.i.d.LoadingState - PhpStorm 2022.2.3  Build #PS-222.4345.15
# 2023-01-13 11:52:31,129 [   2387] SEVERE - #c.i.d.LoadingState - JDK: 17.0.4.1; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2023-01-13 11:52:31,129 [   2387] SEVERE - #c.i.d.LoadingState - OS: Linux
# Info  | RdCoroutineScope          | 14:JobScheduler FJ pool 2/3 | RdCoroutineHost overridden
# 2023-01-13 11:52:35,775 [   7033]   WARN - #c.i.o.a.i.ActionUpdater - 468 ms to grab EDT for CWMTelephonyGroup#update@NavBarToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.CWMTelephonyGroup)
# 2023-01-13 11:52:36,041 [   7299]   WARN - #c.i.o.a.i.ActionUpdater - 112 ms to call on EDT SpaceMainToolBarAction#update@NavBarToolbar (com.intellij.space.vcs.actions.SpaceMainToolBarAction). Use `ActionUpdateThread.BGT`.
# 2023-01-13 11:52:41,997 [  13255]   WARN - #c.i.u.x.Binding - no accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType
# 2023-01-13 11:52:45,899 [  17157]   WARN - #c.i.o.a.i.ActionUpdater - 1523 ms to grab EDT for CWMTelephonyGroup#update@NavBarToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.CWMTelephonyGroup)
# 2023-01-13 11:52:49,701 [  20959]   WARN - #c.i.o.a.i.ActionUpdater - 257 ms to grab EDT for GitCommitWithStagingAreaAction#update@NavBarToolbar (git4idea.index.actions.GitCommitWithStagingAreaAction)
# 2023-01-13 11:55:23,562 [ 174820] SEVERE - c.j.t.m.TerminalTextBuffer - Attempt to get line out of bounds: 12 >= 12
# 2023-01-13 11:55:23,562 [ 174820] SEVERE - c.j.t.m.TerminalTextBuffer - Attempt to get line out of bounds: 12 >= 12
# 2023-01-13 11:55:51,264 [ 202522]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:56:01,308 [ 212566]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:56:18,205 [ 229463]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:56:18,747 [ 230005]   WARN - #c.i.u.x.Binding - no accessors for org.jetbrains.idea.perforce.perforce.ConnectionId
# 2023-01-13 11:57:23,657 [ 294915]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:58:09,707 [ 340965]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:00,815 [ 392073]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:19,934 [ 411192]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:33,137 [ 424395]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:33,139 [ 424397]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:37,750 [ 429008]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:37,753 [ 429011]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:40,775 [ 432033]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:40,777 [ 432035]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:42,228 [ 433486]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:42,231 [ 433489]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:44,293 [ 435551]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:44,295 [ 435553]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:47,089 [ 438347]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:47,091 [ 438349]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:50,097 [ 441355]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 11:59:52,373 [ 443631]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:52,378 [ 443636]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:53,914 [ 445172]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:53,917 [ 445175]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:55,477 [ 446735]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:55,479 [ 446737]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:58,218 [ 449476]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 11:59:58,222 [ 449480]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 11:59:58,948 [ 450206]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 11:59:58,954 [ 450212]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 11:59:59,140 [ 450398]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 11:59:59,141 [ 450399]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:00:03,391 [ 454649]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 12:00:03,392 [ 454650]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:00:03,581 [ 454839]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 12:00:03,582 [ 454840]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:00:04,045 [ 455303]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:04,050 [ 455308]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:04,893 [ 456151]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:00:06,839 [ 458097]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:00:07,509 [ 458767]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:07,515 [ 458773]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:30,716 [ 481974]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:30,719 [ 481977]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:30,722 [ 481980]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:33,519 [ 484777]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:33,543 [ 484801]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:34,136 [ 485394]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:34,150 [ 485408]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:44,867 [ 496125]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:44,869 [ 496127]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:47,534 [ 498792]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:47,537 [ 498795]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:53,999 [ 505257]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:54,002 [ 505260]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:00:55,114 [ 506372]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:00:58,786 [ 510044]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:00:59,182 [ 510440]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:00:59,184 [ 510442]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:00,348 [ 511606]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 12:01:00,350 [ 511608]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:01:00,466 [ 511724]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:01:00,710 [ 511968]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 12:01:00,711 [ 511969]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:01:05,644 [ 516902]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:05,677 [ 516935]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:07,491 [ 518749]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:07,494 [ 518752]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:09,081 [ 520339]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:09,082 [ 520340]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:23,853 [ 535111]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:23,856 [ 535114]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:30,611 [ 541869]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:30,617 [ 541875]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:32,577 [ 543835]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:32,579 [ 543837]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:34,963 [ 546221]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:34,965 [ 546223]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:56,406 [ 567664]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:56,409 [ 567667]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:01:58,485 [ 569743]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:01:58,492 [ 569750]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:05,377 [ 576635]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:05,381 [ 576639]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:05,889 [ 577147]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:05,891 [ 577149]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:07,762 [ 579020]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:07,763 [ 579021]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:08,444 [ 579702]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:08,448 [ 579706]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:09,662 [ 580920]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:09,664 [ 580922]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:12,756 [ 584014]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:12,759 [ 584017]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:15,823 [ 587081]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:15,825 [ 587083]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:16,778 [ 588036]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:16,780 [ 588038]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:24,876 [ 596134]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:24,879 [ 596137]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:27,179 [ 598437]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:27,186 [ 598444]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:27,855 [ 599113]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:27,856 [ 599114]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:29,191 [ 600449]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:29,193 [ 600451]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:31,806 [ 603064]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:31,808 [ 603066]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:34,477 [ 605735]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:02:34,481 [ 605739]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:02:59,368 [ 630626] SEVERE - c.j.t.m.TerminalTextBuffer - Attempt to get line out of bounds: 12 >= 12
# 2023-01-13 12:02:59,370 [ 630628] SEVERE - c.j.t.m.TerminalTextBuffer - Attempt to get line out of bounds: 12 >= 12
# 2023-01-13 12:03:05,496 [ 636754]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:05,498 [ 636756]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:28,575 [ 659833]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:28,577 [ 659835]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:32,156 [ 663414]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:32,158 [ 663416]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:34,137 [ 665395]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:34,139 [ 665397]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:38,729 [ 669987]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:38,737 [ 669995]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:39,416 [ 670674]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:39,419 [ 670677]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:43,142 [ 674400]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:43,144 [ 674402]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:48,314 [ 679572]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:48,314 [ 679572]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:03:51,751 [ 683009]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:03:51,757 [ 683015]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:02,810 [ 754068]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:02,812 [ 754070]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:03,201 [ 754459]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:03,202 [ 754460]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:04,202 [ 755460]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:05:04,268 [ 755526]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 12:05:04,274 [ 755532]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 12:05:05,778 [ 757036]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:05,779 [ 757037]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:07,378 [ 758636]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:07,379 [ 758637]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:08,710 [ 759968]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:08,713 [ 759971]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:40,685 [ 791943]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:40,697 [ 791955]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:46,609 [ 797867]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:46,611 [ 797869]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:48,742 [ 800000]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:05:48,747 [ 800005]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:05:48,747 [ 800005]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:06:02,234 [ 813492]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:06:02,240 [ 813498]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:06:03,086 [ 814344]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:06:03,087 [ 814345]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:08:04,286 [ 935544]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:05,020 [ 936278]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:11,354 [ 942612]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:12,136 [ 943394]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:13,610 [ 944868]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:15,001 [ 946259]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:15,821 [ 947079]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:16,613 [ 947871]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:26,166 [ 957424]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:40,472 [ 971730]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:41,641 [ 972899]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:42,677 [ 973935]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:43,499 [ 974757]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:45,158 [ 976416]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:50,975 [ 982233]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:08:58,734 [ 989992]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:09,835 [1001093]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:10,628 [1001886]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:12,297 [1003555]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:13,811 [1005069]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:15,044 [1006302]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:16,158 [1007416]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:16,919 [1008177]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:26,141 [1017399]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:09:31,845 [1023103]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:10:07,175 [1058433]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:31,567 [1142825]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:34,778 [1146036]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:35,812 [1147070]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:42,977 [1154235]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:45,906 [1157164]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:48,203 [1159461]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:11:51,860 [1163118]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:23,823 [1195081]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:26,516 [1197774]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:29,186 [1200444]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:32,701 [1203959]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:35,171 [1206429]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:38,070 [1209328]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:40,626 [1211884]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:12:54,921 [1226179]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:13:00,901 [1232159]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:13:53,519 [1284777]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:13:54,325 [1285583]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:14:00,489 [1291747]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:14:56,725 [1347983]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:13,553 [1364811]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:18,586 [1369844]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:21,916 [1373174]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:22,752 [1374010]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:26,078 [1377336]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:27,498 [1378756]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:30,702 [1381960]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:31,862 [1383120]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:35,045 [1386303]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:37,426 [1388684]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:39,728 [1390986]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:40,521 [1391779]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:15:41,500 [1392758]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:16:35,556 [1446814]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:18:11,247 [1542505]   WARN - #c.i.o.a.i.ActionUpdater - 330 ms to grab EDT for GitCommitWithStagingAreaAction#update@NavBarToolbar (git4idea.index.actions.GitCommitWithStagingAreaAction)
# 2023-01-13 12:19:37,405 [1628663]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:19:37,408 [1628666]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:19:38,006 [1629264]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:19:38,009 [1629267]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:26:50,469 [2061727]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:27:58,278 [2129536]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:28:01,055 [2132313]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:28:01,521 [2132779]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:28:18,188 [2149446]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:28:21,084 [2152342]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:28:34,607 [2165865]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:29:30,496 [2221754]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:37:39,733 [2710991]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 12:37:39,737 [2710995]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 12:59:40,987 [4032245]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 12:59:49,473 [4040731]   WARN - #c.j.p.PhpIndex - Invalid Signature '
#         $I->dontSee(")'
# 2023-01-13 13:58:07,080 [7538338]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 13:58:35,257 [7566515]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 13:58:38,055 [7569313]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 13:58:40,031 [7571289]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 13:59:04,829 [7596087]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:02:07,242 [7778500]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:02:13,434 [7784692]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:02:37,843 [7809101]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:02:40,164 [7811422]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:02:40,165 [7811423]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:02:57,707 [7828965]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:03:00,309 [7831567]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:03:35,701 [7866959]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:03:37,314 [7868572]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:04:16,939 [7908197]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:04:37,901 [7929159]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:04:40,816 [7932074]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:04:50,281 [7941539]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:10:23,806 [8275064]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:10:23,923 [8275181]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:11:55,566 [8366824]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:11:55,589 [8366847]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:40,273 [8531531]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:40,315 [8531573]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:40,702 [8531960]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:14:40,781 [8532039]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:14:43,302 [8534560]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:43,306 [8534564]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:46,303 [8537561]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:46,305 [8537563]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:46,805 [8538063]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:46,808 [8538066]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:56,131 [8547389]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:56,131 [8547389]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:14:58,814 [8550072]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:14:58,815 [8550073]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:15:00,539 [8551797]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:15:00,593 [8551851]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:15:00,597 [8551855]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:15:20,222 [8571480]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:15:20,272 [8571530]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:15:20,273 [8571531]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:15:20,712 [8571970]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:15:20,714 [8571972]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:16:30,974 [8642232]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:16:30,978 [8642236]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:17:40,923 [8712181]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:17:40,926 [8712184]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:06,112 [8737370]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:07,082 [8738340]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:10,196 [8741454]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:11,820 [8743078]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:13,180 [8744438]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:14,524 [8745782]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:15,808 [8747066]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:17,803 [8749061]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:18:35,895 [8767153]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Collection'
# 2023-01-13 14:19:52,152 [8843410]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:19:53,374 [8844632]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:20:03,064 [8854322]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:20:03,993 [8855251]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:20:19,430 [8870688]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:20:46,627 [8897885]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:20:59,941 [8911199]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:23:57,485 [9088743]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:28:58,503 [9389761]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:34:03,170 [9694428]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:34:03,289 [9694547]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:34:03,289 [9694547]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:35:01,093 [9752351]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:35:01,094 [9752352]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:35:03,114 [9754372]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:35:03,128 [9754386]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:35:04,210 [9755468]   WARN - #c.i.o.a.i.ActionUpdater - 157 ms to call on EDT #getChildren@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2). Use `ActionUpdateThread.BGT`.
# 2023-01-13 14:35:52,075 [9803333]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:35:52,112 [9803370]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:35:52,114 [9803372]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:35:55,022 [9806280]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:35:55,023 [9806281]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:35:56,160 [9807418]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:35:56,161 [9807419]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:00,703 [9811961]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:00,705 [9811963]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:01,491 [9812749]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:01,492 [9812750]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:15,664 [9826922]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:15,773 [9827031]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:29,639 [9840897]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:29,670 [9840928]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:44,844 [9856102]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:44,848 [9856106]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:36:58,860 [9870118]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:36:58,863 [9870121]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:37:15,909 [9887167]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:37:15,914 [9887172]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:08,721 [9939979]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:38:08,763 [9940021]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:38:08,765 [9940023]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:38:10,873 [9942131]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:38:10,899 [9942157]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:38:10,899 [9942157]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:38:11,519 [9942777]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:11,531 [9942789]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:25,253 [9956511]   WARN - #c.j.p.PhpIndex - Invalid Signature '\PHPUnit\Framework\class-string'
# 2023-01-13 14:38:25,279 [9956537]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable'
# 2023-01-13 14:38:25,300 [9956558]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2023-01-13 14:38:27,680 [9958938]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:27,688 [9958946]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:28,957 [9960215]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:28,958 [9960216]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:31,246 [9962504]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:31,248 [9962506]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:32,418 [9963676]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:32,429 [9963687]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:47,836 [9979094]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:38:47,928 [9979186]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:38:59,215 [9990473]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:39:00,873 [9992131]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:39:00,933 [9992191]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:39:24,913 [10016171]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:39:24,954 [10016212]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:41:47,595 [10158853]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:41:47,778 [10159036]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:44:44,555 [10335813]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:44:44,601 [10335859]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:44:57,265 [10348523]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'
# 2023-01-13 14:44:57,410 [10348668]   WARN - #c.j.p.PhpIndex - Invalid Signature '\array'
# 2023-01-13 14:47:48,856 [10520114]   WARN - #c.j.p.PhpIndex - Invalid Signature '\callable'

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/sail .......................................................... DONE
#   laravel/sanctum ....................................................... DONE
#   laravel/tinker ........................................................ DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#   spatie/laravel-ignition ............................................... DONE
#
# 99 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 81 methods added
# TestsCodeception\AcceptanceTester includes modules: PhpBrowser, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# Loaded config default from "/home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    1) resources/views/library/show.blade.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/resources/views/library/show.blade.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/resources/views/library/show.blade.php
# @@ -1,4 +1,6 @@
# -<?php use App\Models\User;?>
# +<?php use App\Models\User;
# +
# +?>
#  <!doctype html>
#  <html>
#  <head>
#
#       ----------- end diff -----------
#
#    2) resources/views/events/show.blade.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/resources/views/events/show.blade.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/resources/views/events/show.blade.php
# @@ -1,4 +1,6 @@
# -<?php use App\Models\User;?>
# +<?php use App\Models\User;
# +
# +?>
#      <!doctype html>
#  <html>
#  <head>
#
#       ----------- end diff -----------
#
#    3) routes/web.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/routes/web.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/routes/web.php
# @@ -16,7 +16,7 @@
#  */
#
#  Route::get('/', function () {
# -    return view('welcome')->with('events', Event::all()->where('accepted','==','1'));
# +    return view('welcome')->with('events', Event::all()->where('accepted', '==', '1'));
#  });
#
#  Route::get('/dashboard', function () {
#
#       ----------- end diff -----------
#
#    4) database/migrations/2022_12_20_190839_create_games_table.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_20_190839_create_games_table.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_20_190839_create_games_table.php
# @@ -4,8 +4,7 @@
#  use Illuminate\Database\Schema\Blueprint;
#  use Illuminate\Support\Facades\Schema;
#
# -return new class extends Migration
# -{
# +return new class () extends Migration {
#      /**
#       * Run the migrations.
#       *
#
#       ----------- end diff -----------
#
#    5) database/migrations/2022_12_28_101439_create_ratings_table.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_28_101439_create_ratings_table.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_28_101439_create_ratings_table.php
# @@ -4,8 +4,7 @@
#  use Illuminate\Database\Schema\Blueprint;
#  use Illuminate\Support\Facades\Schema;
#
# -return new class () extends Migration
# -{
# +return new class () extends Migration {
#      /**
#       * Run the migrations.
#       *
#
#       ----------- end diff -----------
#
#    6) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/seeders/DatabaseSeeder.php
# @@ -17,6 +17,5 @@
#          $this->call(GameSeeder::class);
#          $this->call(CommentsSeeder::class);
#          $this->call(EventSeeder::class);
# -
#      }
#  }
#
#       ----------- end diff -----------
#
#    7) database/seeders/UsersSeeder.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/seeders/UsersSeeder.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/seeders/UsersSeeder.php
# @@ -12,7 +12,6 @@
#       */
#      public function run(): void
#      {
# -
#          DB::table('users')->insert([
#              'email' => 'john.doe@gmail.com',
#              'password' => bcrypt('secret'),
# @@ -54,7 +53,5 @@
#              'age' => 21,
#              'socialized' => false,
#          ]);
# -
#      }
# -
#  }
#
#       ----------- end diff -----------
#
#    8) app/Http/Controllers/CommentController.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/CommentController.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/CommentController.php
# @@ -52,7 +52,6 @@
#          //route do mozliwej zmiany - zalezy gdzie dostepne bedzie usuwanie komentarza
#          return view('library.index')->with('games', Game::all());
#      }
# -
#  }
#
#  /*$comments = User::find(1)->comments; // w users dziala identycznie tyle ze zwracana wartosc to jeden user a tu array commentsow
#
#       ----------- end diff -----------
#
#    9) app/Http/Controllers/ProfileController.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php
# @@ -26,18 +26,17 @@
#              'user' => $request->user(),
#          ])->with('events', Event::all())->with('games', Game::all())->with('auctions', Auction::all());
#      }
# -    public function admin_update(string $element,int $id): RedirectResponse
# +    public function admin_update(string $element, int $id): RedirectResponse
#      {
# -        if($element=="Event")
# -        {
# +        if ($element=="Event") {
#              $data = Event::find($id);
#              $data->accepted = 1;
#              $data->save();
# -        } else if($element=="Game") {
# +        } elseif ($element=="Game") {
#              $data = Game::find($id);
#              $data->accepted = 1;
#              $data->save();
# -        } else if($element=="Auction") {
# +        } elseif ($element=="Auction") {
#              $data = Auction::find($id);
#              $data->accepted = 1;
#              $data->save();
# @@ -44,22 +43,20 @@
#          }
#          return redirect('/profile')->with('events', Event::all())->with('games', Game::all())->with('auctions', Auction::all());
#      }
# -    public function admin_destroy(string $element,int $id): RedirectResponse
# +    public function admin_destroy(string $element, int $id): RedirectResponse
#      {
# -            if ($element=="Event")
# -            {
# -                $event=Event::find($id);
# -                $event->delete();
# -
# -            } else if ($element=="Game") {
# -                $game=Game::find($id);
# -                $game->delete();
# -            } else if ($element=="Auction") {
# -                $auction=Auction::find($id);
# -                $auction->delete();
# -            }
# +        if ($element=="Event") {
# +            $event=Event::find($id);
# +            $event->delete();
# +        } elseif ($element=="Game") {
# +            $game=Game::find($id);
# +            $game->delete();
# +        } elseif ($element=="Auction") {
# +            $auction=Auction::find($id);
# +            $auction->delete();
# +        }
#          return redirect('/profile')->with('events', Event::all())->with('games', Game::all())->with('auctions', Auction::all());
# -           }
# +    }
#      /**
#       * Update the user's profile information.
#       */
#
#       ----------- end diff -----------
#
#   10) app/Http/Controllers/GameController.php
#       ---------- begin diff ----------
# --- /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/GameController.php
# +++ /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/GameController.php
# @@ -52,7 +52,6 @@
#          $gamers = DB::table('game_user')->where('game_id', '=', $game_id)->count();
#          return $gamers;
#      }
# -
#  }
#
#  /*
#
#       ----------- end diff -----------
#
#
# Checked all files in 0.601 seconds, 18.000 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#  ! [NOTE] The Xdebug PHP extension is active, but "--xdebug" is not used. This
#  !        may slow down performance and the process will not halt at
#  !        breakpoints.
#
#   0/95 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0% 20/95 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  21% 40/95 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  42% 60/95 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░]  63% 75/95 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  78% 95/95 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Http/Controllers/AuctionController.php
#  ------ ---------------------------------------------------------------------
#   18     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#   36     Property App\Models\Auction::$price (float) does not accept mixed.
#   40     Cannot call method getAuthIdentifier() on App\Models\User|null.
#   40     Property App\Models\Auction::$user_id (int) does not accept mixed.
#   52     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#  ------ ---------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------
#   Line   app/Http/Controllers/CommentController.php
#  ------ --------------------------------------------------------------------
#   22     Cannot call method getAuthIdentifier() on App\Models\User|null.
#   22     Property App\Models\Comment::$user_id (int) does not accept mixed.
#   23     Property App\Models\Comment::$game_id (int) does not accept mixed.
#  ------ --------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Http/Controllers/EventController.php
#  ------ ---------------------------------------------------------------------
#   14     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#  ------ ---------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Http/Controllers/GameController.php
#  ------ ---------------------------------------------------------------------
#   17     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#   47     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#  ------ ---------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------------
#   Line   app/Http/Controllers/ProfileController.php
#  ------ ----------------------------------------------------------------------
#   34     Cannot access property $accepted on App\Models\Event|null.
#   35     Cannot call method save() on App\Models\Event|null.
#   38     Cannot access property $accepted on App\Models\Game|null.
#   39     Cannot call method save() on App\Models\Game|null.
#   42     Cannot access property $accepted on App\Models\Auction|null.
#   43     Cannot call method save() on App\Models\Auction|null.
#   52     Cannot call method delete() on App\Models\Event|null.
#   56     Cannot call method delete() on App\Models\Game|null.
#   59     Cannot call method delete() on App\Models\Auction|null.
#   73     Property App\Models\User::$username (string|null) does not accept
#          mixed.
#   74     Property App\Models\User::$city (string|null) does not accept mixed.
#   75     Property App\Models\User::$age (int|null) does not accept mixed.
#  ------ ----------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Http/Controllers/RatingController.php
#  ------ ---------------------------------------------------------------------
#   15     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#   15     Cannot call method getAuthIdentifier() on App\Models\User|null.
#   21     Cannot call method getAuthIdentifier() on App\Models\User|null.
#   21     Property App\Models\Rating::$user_id (int) does not accept mixed.
#   22     Property App\Models\Rating::$rating (int) does not accept mixed.
#   23     Property App\Models\Rating::$game_id (int) does not accept mixed.
#   28     Method App\Http\Controllers\RatingController::avg_rating() has
#          parameter $game_id with no type specified.
#   31     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#   43     Method App\Http\Controllers\RatingController::numberOfRatings() has
#          parameter $game_id with no type specified.
#  ------ ---------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   routes/web.php
#  ------ ---------------------------------------------------------------------
#   19     Called 'where' on Laravel collection, but could have been retrieved
#          as a query.
#  ------ ---------------------------------------------------------------------
#
#  ------ -------------------------------------------------------------------
#   Line   tests/Feature/Auth/EmailVerificationTest.php
#  ------ -------------------------------------------------------------------
#   63     Parameter #1 $string of function sha1 expects string, string|null
#          given.
#  ------ -------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   tests/Feature/Auth/PasswordUpdateTest.php
#  ------ ---------------------------------------------------------------------
#   31     Parameter #2 $hashedValue of static method
#          Illuminate\Hashing\HashManager::check() expects string, string|null
#          given.
#  ------ ---------------------------------------------------------------------
#
#
#  [ERROR] Found 35 errors

# %%
! vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 20 --exclude vendor --exclude tests* --exclude config --exclude storage
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# Found 5 clones with 28 duplicated lines in 6 files:
#
#   - /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_22_184203_create_comments_table.php:18-34 (16 lines)
#     /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_28_101439_create_ratings_table.php:19-35
#
#   - /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php:45-51 (6 lines)
#     /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php:61-67
#
#   - /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php:27-30 (3 lines)
#     /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/ProfileController.php:45-48
#
#   - /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_22_184203_create_comments_table.php:20-22 (2 lines)
#     /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/database/migrations/2022_12_25_213524_create_game_user_table.php:19-21
#
#   - /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/CommentController.php:36-37 (1 lines)
#     /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/RatingController.php:25-26
#
# 0.51% duplicated lines out of 5523 total lines of code.
# Average size of duplication is 5 lines, largest clone has 16 of lines
#
# Time: 00:00.015, Memory: 8.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! php artisan migrate:fresh
# Out:
#   Dropping all tables .............................................. 35ms DONE
#
#    INFO  Preparing database.
#
#   Creating migration table ......................................... 56ms DONE
#
#    INFO  Running migrations.
#
#   2014_10_12_000000_create_users_table ............................ 121ms DONE
#   2014_10_12_100000_create_password_resets_table ................... 86ms DONE
#   2019_08_19_000000_create_failed_jobs_table ....................... 70ms DONE
#   2019_12_14_000001_create_personal_access_tokens_table ........... 119ms DONE
#   2022_12_18_153238_create_auctions_table ......................... 157ms DONE
#   2022_12_20_190839_create_games_table ............................. 47ms DONE
#   2022_12_22_184203_create_comments_table ......................... 244ms DONE
#   2022_12_23_154528_create_events_table ............................ 53ms DONE
#   2022_12_25_213524_create_game_user_table ........................ 238ms DONE
#   2022_12_25_214045_create_event_user_table ....................... 331ms DONE
#   2022_12_28_101439_create_ratings_table .......................... 213ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................ 468.44 ms DONE
#
#   Database\Seeders\AuctionsSeeder .................................... RUNNING
#   Database\Seeders\AuctionsSeeder .............................. 17.82 ms DONE
#
#   Database\Seeders\GameSeeder ........................................ RUNNING
#   Database\Seeders\GameSeeder .................................. 52.70 ms DONE
#
#   Database\Seeders\CommentsSeeder .................................... RUNNING
#   Database\Seeders\CommentsSeeder .............................. 30.99 ms DONE
#
#   Database\Seeders\EventSeeder ....................................... RUNNING
#   Database\Seeders\EventSeeder ................................. 27.92 ms DONE

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/_data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# m##################) ⠴ reify:@esbuild/android-arm: timing reifyNode:node_module
# up to date, audited 94 packages in 3s
#
# 20 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v3.2.4 building for production...
# transforming (1) resources/js/app.jstransforming (4) node_modules/axios/index.jstransforming (8) node_modules/axios/lib/axios.jstransforming (10) node_modules/axios/lib/utils.jstransforming (32) node_modules/axios/lib/adapters/index.js✓ 49 modules transformed.
# rendering chunks (1)...rendering chunks (2)...public/build/manifest.json             0.25 KiB
# public/build/assets/app.b7a95ced.css   31.44 KiB / gzip: 6.13 KiB
# public/build/assets/app.d426e523.js    135.11 KiB / gzip: 49.03 KiB

# %%
! php artisan test
# Out:
#    PASS  Tests\Unit\ExampleTest
#   ✓ that true is true
#
#    FAIL  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered
#   ⨯ users can authenticate using the login screen
#   ⨯ users can not authenticate with invalid password
#
#    FAIL  Tests\Feature\Auth\EmailVerificationTest
#   ⨯ email verification screen can be rendered
#   ⨯ email can be verified
#   ⨯ email is not verified with invalid hash
#
#    FAIL  Tests\Feature\Auth\PasswordConfirmationTest
#   ⨯ confirm password screen can be rendered
#   ⨯ password can be confirmed
#   ⨯ password is not confirmed with invalid password
#
#    FAIL  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered
#   ⨯ reset password link can be requested
#   ⨯ reset password screen can be rendered
#   ⨯ password can be reset with valid token
#
#    FAIL  Tests\Feature\Auth\PasswordUpdateTest
#   ⨯ password can be updated
#   ⨯ correct password must be provided to update password
#
#    FAIL  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered
#   ⨯ new users can register
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response
#
#    FAIL  Tests\Feature\ProfileTest
#   ⨯ profile page is displayed
#   ⨯ profile information can be updated
#   ⨯ email verification status is unchanged when the email address is unchanged
#   ⨯ user can delete their account
#   ⨯ correct password must be provided to delete account
#
#   ---
#
#   • Tests\Feature\Auth\AuthenticationTest > users can authenticate using the login screen
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Lucio Balistreri, ramon.schiller@example.net, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, V5UStkjRcb, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\AuthenticationTest > users can not authenticate with invalid password
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Josephine Runolfsdottir, stanford.collier@example.net, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, rR5GuybV1D, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\EmailVerificationTest > email verification screen can be rendered
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Derrick Schumm, witting.jay@example.org, ?, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, FVtlDHwiPg, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\EmailVerificationTest > email can be verified
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[HY000]: General error: 1364 Field 'username' doesn't have a default value (SQL: insert into `users` (`email`, `password`, `updated_at`, `created_at`) values (name@example.com, $2y$04$T9Zy5TXN1C71yN.wDe2irOcsaEMtOqVVEtkb2mffcnadAr46JmdtC, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\EmailVerificationTest > email is not verified with invalid hash
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Arlo Gleason, schroeder.melvin@example.org, ?, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, sxnIcf6qxT, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordConfirmationTest > confirm password screen can be rendered
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Macey Legros, dexter40@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, jcfecFVc1Z, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordConfirmationTest > password can be confirmed
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Miss Kailee Russel Sr., jarrod.davis@example.org, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, E8hxCm2vWH, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordConfirmationTest > password is not confirmed with invalid password
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Merlin Powlowski Sr., carlo46@example.org, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, L04cxLVuv3, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordResetTest > reset password link can be requested
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Bridgette Kovacek PhD, umurray@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, KDpvNzQzfx, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordResetTest > reset password screen can be rendered
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Dr. Chandler Harvey, jack64@example.net, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, rtKTAKRnTU, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordResetTest > password can be reset with valid token
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Grayce Kassulke DVM, ressie35@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, Uszwl78IKJ, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordUpdateTest > password can be updated
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Jovan Greenholt, langosh.earnest@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, DZqpN6SW4V, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\PasswordUpdateTest > correct password must be provided to update password
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Dr. Marina Zieme, harber.francisco@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, 1NgS54Kr42, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\Auth\RegistrationTest > new users can register
#   The user is not authenticated
#   Failed asserting that false is true.
#
#   The following exception occurred during the last request:
#
#   PDOException: SQLSTATE[HY000]: General error: 1364 Field 'username' doesn't have a default value in /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php:545
#   Stack trace:
#   #0 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(545): PDOStatement->execute()
#   #1 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(753): Illuminate\Database\Connection->Illuminate\Database\{closure}()
#   #2 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(720): Illuminate\Database\Connection->runQueryCallback()
#   #3 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(546): Illuminate\Database\Connection->run()
#   #4 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(498): Illuminate\Database\Connection->statement()
#   #5 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Query/Processors/Processor.php(32): Illuminate\Database\Connection->insert()
#   #6 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Query/Builder.php(3266): Illuminate\Database\Query\Processors\Processor->processInsertGetId()
#   #7 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(1861): Illuminate\Database\Query\Builder->insertGetId()
#   #8 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1322): Illuminate\Database\Eloquent\Builder->__call()
#   #9 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1287): Illuminate\Database\Eloquent\Model->insertAndSetId()
#   #10 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1128): Illuminate\Database\Eloquent\Model->performInsert()
#   #11 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(978): Illuminate\Database\Eloquent\Model->save()
#   #12 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Support/helpers.php(306): Illuminate\Database\Eloquent\Builder->Illuminate\Database\Eloquent\{closure}()
#   #13 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(979): tap()
#   #14 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Support/Traits/ForwardsCalls.php(23): Illuminate\Database\Eloquent\Builder->create()
#   #15 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(2321): Illuminate\Database\Eloquent\Model->forwardCallTo()
#   #16 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(2333): Illuminate\Database\Eloquent\Model->__call()
#   #17 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/Auth/RegisteredUserController.php(48): Illuminate\Database\Eloquent\Model::__callStatic()
#   #18 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Controller.php(54): App\Http\Controllers\Auth\RegisteredUserController->store()
#   #19 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/ControllerDispatcher.php(43): Illuminate\Routing\Controller->callAction()
#   #20 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Route.php(260): Illuminate\Routing\ControllerDispatcher->dispatch()
#   #21 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Route.php(205): Illuminate\Routing\Route->runController()
#   #22 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(727): Illuminate\Routing\Route->run()
#   #23 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(141): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
#   #24 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Middleware/RedirectIfAuthenticated.php(30): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #25 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): App\Http\Middleware\RedirectIfAuthenticated->handle()
#   #26 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(50): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #27 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Routing\Middleware\SubstituteBindings->handle()
#   #28 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(78): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #29 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
#   #30 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #31 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
#   #32 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #33 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
#   #34 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Session\Middleware\StartSession->handle()
#   #35 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #36 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
#   #37 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(67): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #38 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Cookie\Middleware\EncryptCookies->handle()
#   #39 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(116): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #40 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(728): Illuminate\Pipeline\Pipeline->then()
#   #41 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(705): Illuminate\Routing\Router->runRouteWithinStack()
#   #42 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(669): Illuminate\Routing\Router->runRoute()
#   #43 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(658): Illuminate\Routing\Router->dispatchToRoute()
#   #44 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(190): Illuminate\Routing\Router->dispatch()
#   #45 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(141): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
#   #46 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #47 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
#   #48 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
#   #49 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #50 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(40): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
#   #51 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
#   #52 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #53 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\ValidatePostSize->handle()
#   #54 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(86): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #55 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
#   #56 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #57 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Http\Middleware\HandleCors->handle()
#   #58 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(39): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #59 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Http\Middleware\TrustProxies->handle()
#   #60 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(116): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #61 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(165): Illuminate\Pipeline\Pipeline->then()
#   #62 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(134): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
#   #63 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(545): Illuminate\Foundation\Http\Kernel->handle()
#   #64 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(340): Illuminate\Foundation\Testing\TestCase->call()
#   #65 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests/Feature/Auth/RegistrationTest.php(23): Illuminate\Foundation\Testing\TestCase->post()
#   #66 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1548): Tests\Feature\Auth\RegistrationTest->test_new_users_can_register()
#   #67 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1154): PHPUnit\Framework\TestCase->runTest()
#   #68 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestResult.php(728): PHPUnit\Framework\TestCase->runBare()
#   #69 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(904): PHPUnit\Framework\TestResult->run()
#   #70 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestCase->run()
#   #71 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestSuite->run()
#   #72 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestSuite->run()
#   #73 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(661): PHPUnit\Framework\TestSuite->run()
#   #74 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/Command.php(144): PHPUnit\TextUI\TestRunner->run()
#   #75 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/Command.php(97): PHPUnit\TextUI\Command->run()
#   #76 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/phpunit(98): PHPUnit\TextUI\Command::main()
#   #77 {main}
#
#   Next Illuminate\Database\QueryException: SQLSTATE[HY000]: General error: 1364 Field 'username' doesn't have a default value (SQL: insert into `users` (`email`, `password`, `updated_at`, `created_at`) values (test@example.com, $2y$04$vl/tL1a8FqusnOIMKsubF.0deltC1MrI/T9yPdSAgRjP3aZlA1aai, 2022-12-22 18:07:40, 2022-12-22 18:07:40)) in /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#   Stack trace:
#   #0 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(720): Illuminate\Database\Connection->runQueryCallback()
#   #1 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(546): Illuminate\Database\Connection->run()
#   #2 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Connection.php(498): Illuminate\Database\Connection->statement()
#   #3 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Query/Processors/Processor.php(32): Illuminate\Database\Connection->insert()
#   #4 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Query/Builder.php(3266): Illuminate\Database\Query\Processors\Processor->processInsertGetId()
#   #5 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(1861): Illuminate\Database\Query\Builder->insertGetId()
#   #6 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1322): Illuminate\Database\Eloquent\Builder->__call()
#   #7 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1287): Illuminate\Database\Eloquent\Model->insertAndSetId()
#   #8 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(1128): Illuminate\Database\Eloquent\Model->performInsert()
#   #9 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(978): Illuminate\Database\Eloquent\Model->save()
#   #10 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Support/helpers.php(306): Illuminate\Database\Eloquent\Builder->Illuminate\Database\Eloquent\{closure}()
#   #11 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Builder.php(979): tap()
#   #12 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Support/Traits/ForwardsCalls.php(23): Illuminate\Database\Eloquent\Builder->create()
#   #13 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(2321): Illuminate\Database\Eloquent\Model->forwardCallTo()
#   #14 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Database/Eloquent/Model.php(2333): Illuminate\Database\Eloquent\Model->__call()
#   #15 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Controllers/Auth/RegisteredUserController.php(48): Illuminate\Database\Eloquent\Model::__callStatic()
#   #16 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Controller.php(54): App\Http\Controllers\Auth\RegisteredUserController->store()
#   #17 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/ControllerDispatcher.php(43): Illuminate\Routing\Controller->callAction()
#   #18 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Route.php(260): Illuminate\Routing\ControllerDispatcher->dispatch()
#   #19 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Route.php(205): Illuminate\Routing\Route->runController()
#   #20 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(727): Illuminate\Routing\Route->run()
#   #21 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(141): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
#   #22 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/app/Http/Middleware/RedirectIfAuthenticated.php(30): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #23 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): App\Http\Middleware\RedirectIfAuthenticated->handle()
#   #24 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(50): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #25 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Routing\Middleware\SubstituteBindings->handle()
#   #26 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(78): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #27 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
#   #28 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #29 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
#   #30 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #31 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
#   #32 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Session\Middleware\StartSession->handle()
#   #33 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #34 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
#   #35 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(67): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #36 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Cookie\Middleware\EncryptCookies->handle()
#   #37 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(116): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #38 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(728): Illuminate\Pipeline\Pipeline->then()
#   #39 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(705): Illuminate\Routing\Router->runRouteWithinStack()
#   #40 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(669): Illuminate\Routing\Router->runRoute()
#   #41 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(658): Illuminate\Routing\Router->dispatchToRoute()
#   #42 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(190): Illuminate\Routing\Router->dispatch()
#   #43 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(141): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
#   #44 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #45 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
#   #46 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
#   #47 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #48 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(40): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
#   #49 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
#   #50 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #51 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\ValidatePostSize->handle()
#   #52 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(86): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #53 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
#   #54 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #55 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Http\Middleware\HandleCors->handle()
#   #56 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(39): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #57 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(180): Illuminate\Http\Middleware\TrustProxies->handle()
#   #58 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(116): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
#   #59 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(165): Illuminate\Pipeline\Pipeline->then()
#   #60 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(134): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
#   #61 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(545): Illuminate\Foundation\Http\Kernel->handle()
#   #62 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(340): Illuminate\Foundation\Testing\TestCase->call()
#   #63 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests/Feature/Auth/RegistrationTest.php(23): Illuminate\Foundation\Testing\TestCase->post()
#   #64 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1548): Tests\Feature\Auth\RegistrationTest->test_new_users_can_register()
#   #65 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1154): PHPUnit\Framework\TestCase->runTest()
#   #66 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestResult.php(728): PHPUnit\Framework\TestCase->runBare()
#   #67 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(904): PHPUnit\Framework\TestResult->run()
#   #68 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestCase->run()
#   #69 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestSuite->run()
#   #70 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(673): PHPUnit\Framework\TestSuite->run()
#   #71 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(661): PHPUnit\Framework\TestSuite->run()
#   #72 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/Command.php(144): PHPUnit\TextUI\TestRunner->run()
#   #73 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/src/TextUI/Command.php(97): PHPUnit\TextUI\Command->run()
#   #74 /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/vendor/phpunit/phpunit/phpunit(98): PHPUnit\TextUI\Command::main()
#   #75 {main}
#
#   ----------------------------------------------------------------------------------
#
#   SQLSTATE[HY000]: General error: 1364 Field 'username' doesn't have a default value (SQL: insert into `users` (`email`, `password`, `updated_at`, `created_at`) values (test@example.com, $2y$04$vl/tL1a8FqusnOIMKsubF.0deltC1MrI/T9yPdSAgRjP3aZlA1aai, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at tests/Feature/Auth/RegistrationTest.php:29
#      25▕             'password' => 'password',
#      26▕             'password_confirmation' => 'password',
#      27▕         ]);
#      28▕
#   ➜  29▕         $this->assertAuthenticated();
#      30▕         $response->assertRedirect(RouteServiceProvider::HOME);
#      31▕     }
#      32▕ }
#      33▕
#
#   • Tests\Feature\ProfileTest > profile page is displayed
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Adonis Cummerata, ava80@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, Q9QfEqZO4k, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\ProfileTest > profile information can be updated
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Hulda Bechtelar, hortense.bednar@example.org, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, K7WQQs2g7t, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\ProfileTest > email verification status is unchanged when the email address is unchanged
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Hershel D'Amore, aabshire@example.com, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, VKmzKV3WpN, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\ProfileTest > user can delete their account
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Kobe Osinski, freddy29@example.net, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, hsENa22mRV, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#   • Tests\Feature\ProfileTest > correct password must be provided to delete account
#    PHPUnit\Framework\ExceptionWrapper
#
#   SQLSTATE[42S22]: Column not found: 1054 Unknown column 'name' in 'field list' (SQL: insert into `users` (`name`, `email`, `email_verified_at`, `password`, `remember_token`, `updated_at`, `created_at`) values (Gudrun Connelly, shanie61@example.net, 2022-12-22 18:07:40, $2y$10$92IXUNpkjO0rOQ5byMi.Ye4oKoEa3Ro9llC/.og/at2.uheWG/igi, bcoxG6w5uX, 2022-12-22 18:07:40, 2022-12-22 18:07:40))
#
#   at vendor/laravel/framework/src/Illuminate/Database/Connection.php:760
#     756▕         // If an exception occurs when attempting to run a query, we'll format the error
#     757▕         // message to include the bindings with SQL, which will make this exception a
#     758▕         // lot more helpful to the developer instead of just the database's errors.
#     759▕         catch (Exception $e) {
#   ➜ 760▕             throw new QueryException(
#     761▕                 $query, $this->prepareBindings($bindings), $e
#     762▕             );
#     763▕         }
#     764▕     }
#
#
#   Tests:  19 failed, 5 passed
#   Time:   2.04s

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! vendor/bin/codecept run
# Out:
# Codeception PHP Testing Framework v5.0.4 https://helpukrainewin.org
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
#
# TestsCodeception.Acceptance Tests (3) ------------------------------------------
# ✖ Test00_HomepageCest: See Laravel links on homepage (0.13s)
# - Test01_CommentsCest: See comments from DB displayed on page  2022-12-22 19:07:42 ................................................... ~ 1s
# ✔ Test01_CommentsCest: See comments from DB displayed on page (0.12s)
# - Test02_LoginCest: Login with existing user  2022-12-22 19:07:44 ................................................... ~ 0s
#   2022-12-22 19:07:44 ................................................... ~ 0s
# ✖ Test02_LoginCest: Login with existing user (0.35s)
# --------------------------------------------------------------------------------
# Time: 00:04.647, Memory: 14.00 MB
#
# There were 2 failures:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:homepageTest
#  Step  See in title "Laravel"
#  Fail  Tag element with '<title>' was not found.
#
# Scenario Steps:
#
#  2. $I->seeInTitle("Laravel") at tests_codeception/Acceptance/Test00_HomepageCest.php:15
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# Artifacts:
#
# Html: /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00_HomepageCest.homepageTest.fail.html
# Response: /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00_HomepageCest.homepageTest.fail.html
# 2) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:loginTest
#  Step  See "John Doe"
#  Fail  Failed asserting that on page /dashboard
# -->  Laravel Dashboard Profile Log Out Dashboard john.doe@gmail.com Profile Log Out Dashboard You're logged in!
# --> contains "John Doe".
#
# Scenario Steps:
#
#  7. $I->see("John Doe") at tests_codeception/Acceptance/Test02_LoginCest.php:24
#  6. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:22
#  5. $I->click("Log in") at tests_codeception/Acceptance/Test02_LoginCest.php:20
#  4. $I->fillField("password","secret") at tests_codeception/Acceptance/Test02_LoginCest.php:18
#  3. $I->fillField("email","john.doe@gmail.com") at tests_codeception/Acceptance/Test02_LoginCest.php:17
#  2. $I->seeCurrentUrlEquals("/login") at tests_codeception/Acceptance/Test02_LoginCest.php:15
#
# Artifacts:
#
# Html: /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02_LoginCest.loginTest.fail.html
# Response: /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02_LoginCest.loginTest.fail.html
#
# FAILURES!
# Tests: 3, Assertions: 10, Failures: 2.
#   2022-12-22 19:07:45 ................................................... ~ 0s
#   2022-12-22 19:07:45 ................................................... ~ 0s
#   2022-12-22 19:07:45 ................................................... ~ 0s
#   2022-12-22 19:07:45 ................................................... ~ 0s

# %%
! killall php php8.1
# Out:
# php8.1: no process found

# %%
# %cd ..
# Out:
# /home/student/php_2022_platforma_dla_fanow_planszowek/09_laravel_tdd

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
